# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



file_path2016 = r"C:\Users\franz\OneDrive\Desktop\TUHH\3. Semester\00_TechLabs\Daten\csv_2016/Unfallorte_2016_LinRef.txt"
file_path2017 = r"C:\Users\franz\OneDrive\Desktop\TUHH\3. Semester\00_TechLabs\Daten\csv_2017/Unfallorte_2017_LinRef.txt"
file_path2018 = r"C:\Users\franz\OneDrive\Desktop\TUHH\3. Semester\00_TechLabs\Daten\csv_2018/Unfallorte2018_LinRef.txt"
file_path2019 = r"C:\Users\franz\OneDrive\Desktop\TUHH\3. Semester\00_TechLabs\Daten\csv_2019/Unfallorte2019_LinRef.txt"

# %%
df2016 = pd.read_csv(file_path2016, sep=";")
df2017 = pd.read_csv(file_path2017, sep=";")
df2018 = pd.read_csv(file_path2018, sep=";")
df2019 = pd.read_csv(file_path2019, sep=";")
# Out:
# C:\Users\franz\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2016.describe()
# Out:
#                  FID       OBJECTID          ULAND        UREGBEZ  \
# count  151673.000000  151673.000000  151673.000000  151673.000000
# mean    75836.000000   75837.000000       7.588325       3.058428
# std     43784.368027   43784.368027       3.100031       2.136635
# min         0.000000       1.000000       1.000000       0.000000
# 25%     37918.000000   37919.000000       6.000000       1.000000
# 50%     75836.000000   75837.000000       8.000000       3.000000
# 75%    113754.000000  113755.000000       9.000000       5.000000
# max    151672.000000  151673.000000      14.000000       7.000000
#
#               UKREIS      UGEMEINDE     UJAHR         UMONAT        USTUNDE  \
# count  151673.000000  151673.000000  151673.0  151673.000000  151673.000000
# mean       40.645560      79.723425    2016.0       6.754353      13.296908
# std        25.549715     111.305504       0.0       3.220686       4.857073
# ...

# %%
dfrad2016=df2016
indexNames1= dfrad2016[dfrad2016["IstRad"]==0].index
dfrad2016.drop(indexNames1,inplace=True)
dfrad2016.describe()
# Out:
#                 FID      OBJECTID         ULAND       UREGBEZ        UKREIS  \
# count   36094.00000   36094.00000  36094.000000  36094.000000  36094.000000
# mean    95741.58126   95742.58126      7.494376      2.985870     39.364576
# std     42483.93679   42483.93679      3.462911      2.254318     26.552501
# min         3.00000       4.00000      1.000000      0.000000      1.000000
# 25%     70589.75000   70590.75000      6.000000      1.000000     13.000000
# 50%    106025.50000  106026.50000      8.000000      3.000000     34.000000
# 75%    129485.75000  129486.75000      9.000000      5.000000     62.000000
# max    151670.00000  151671.00000     14.000000      7.000000     90.000000
#
#           UGEMEINDE    UJAHR        UMONAT       USTUNDE    UWOCHENTAG  ...  \
# count  36094.000000  36094.0  36094.000000  36094.000000  36094.000000  ...
# mean      72.673962   2016.0      6.910678     13.425722      4.123068  ...
# ...

# %%
dfland2016=dfrad2016
indexNames1= dfland2016[dfland2016["ULAND"]!=2].index
dfland2016.drop(indexNames1,inplace=True)
dfland2016.describe()
# Out:
#                 FID      OBJECTID   ULAND      UREGBEZ       UKREIS  \
# count   2206.000000   2206.000000  2206.0  2206.000000  2206.000000
# mean   87810.066183  87811.066183     2.0     3.322756     6.644152
# std    26929.384655  26929.384655     0.0     1.700500     4.684982
# min     6188.000000   6189.000000     2.0     1.000000     1.000000
# 25%    95210.500000  95211.500000     2.0     2.000000     3.000000
# 50%    96654.000000  96655.000000     2.0     3.000000     5.000000
# 75%    98069.750000  98070.750000     2.0     5.000000     9.000000
# max    99950.000000  99951.000000     2.0     7.000000    20.000000
#
#          UGEMEINDE   UJAHR       UMONAT      USTUNDE   UWOCHENTAG  ...  \
# count  2206.000000  2206.0  2206.000000  2206.000000  2206.000000  ...
# mean    347.585222  2016.0     6.908432    13.311423     4.125567  ...
# std     168.803837     0.0     2.853132     4.583766     1.705030  ...
# ...

# %%
df2017 = pd.read_csv(file_path2017, sep=";")
dfrad2017=df2017
indexNames1= dfrad2017[dfrad2017["IstRad"]==0].index
dfrad2017.drop(indexNames1,inplace=True)
dfland2017=dfrad2017
indexNames1= dfland2017[dfland2017["ULAND"]!=2].index
dfland2017.drop(indexNames1,inplace=True)
dfland2017.describe()
# Out:
# C:\Users\franz\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             OBJECTID   ULAND      UREGBEZ       UKREIS    UGEMEINDE   UJAHR  \
# count    2180.000000  2180.0  2180.000000  2180.000000  2180.000000  2180.0
# mean   110946.188532     2.0     3.313303     6.585321   346.631193  2017.0
# std     36501.674456     0.0     1.678224     4.590887   166.385702     0.0
# min      6263.000000     2.0     1.000000     1.000000   101.000000  2017.0
# 25%    122152.500000     2.0     2.000000     3.000000   212.000000  2017.0
# 50%    123664.000000     2.0     3.000000     5.000000   319.000000  2017.0
# 75%    125026.500000     2.0     5.000000     9.000000   504.000000  2017.0
# max    126861.000000     2.0     7.000000    20.000000   718.000000  2017.0
#
# ...

# %%
df2018 = pd.read_csv(file_path2018, sep=";")
dfrad2018=df2018
indexNames1= dfrad2018[dfrad2018["IstRad"]==0].index
dfrad2018.drop(indexNames1,inplace=True)
dfland2018=dfrad2018
indexNames1= dfland2018[dfland2018["ULAND"]!=2].index
dfland2018.drop(indexNames1,inplace=True)
dfland2018.describe()
# Out:
#           OBJECTID_1   ULAND      UREGBEZ       UKREIS    UGEMEINDE   UJAHR  \
# count    2323.000000  2323.0  2323.000000  2323.000000  2323.000000  2323.0
# mean   112685.426604     2.0     3.365476     6.459320   351.430478  2018.0
# std     37537.282128     0.0     1.705328     4.582712   169.116610     0.0
# min      6023.000000     2.0     1.000000     1.000000   101.000000  2018.0
# 25%    124400.500000     2.0     2.000000     3.000000   212.000000  2018.0
# 50%    125908.000000     2.0     3.000000     5.000000   320.000000  2018.0
# 75%    127236.500000     2.0     5.000000     9.000000   509.500000  2018.0
# max    129220.000000     2.0     7.000000    20.000000   717.000000  2018.0
#
#             UMONAT      USTUNDE   UWOCHENTAG   UKATEGORIE         UART  \
# count  2323.000000  2323.000000  2323.000000  2323.000000  2323.000000
# mean      6.959105    13.100301     4.034438     2.907878     3.586311
# ...

# %%
df2019 = pd.read_csv(file_path2019, sep=";")
dfrad2019=df2019
indexNames1= dfrad2019[dfrad2019["IstRad"]==0].index
dfrad2019.drop(indexNames1,inplace=True)
dfland2019=dfrad2019
indexNames1= dfland2019[dfland2019["ULAND"]!=2].index
dfland2019.drop(indexNames1,inplace=True)
dfland2019.describe()
# Out:
#             OBJECTID   ULAND      UREGBEZ       UKREIS    UGEMEINDE   UJAHR  \
# count    2310.000000  2310.0  2310.000000  2310.000000  2310.000000  2310.0
# mean   144263.064069     2.0     3.341126     6.607792   349.396104  2019.0
# std     46958.886822     0.0     1.723050     4.648617   170.842595     0.0
# min      6155.000000     2.0     1.000000     1.000000   101.000000  2019.0
# 25%    158750.250000     2.0     2.000000     3.000000   210.000000  2019.0
# 50%    160183.000000     2.0     3.000000     5.000000   319.500000  2019.0
# 75%    161550.750000     2.0     5.000000     9.000000   509.000000  2019.0
# max    163331.000000     2.0     7.000000    20.000000   717.000000  2019.0
#
#             UMONAT      USTUNDE   UWOCHENTAG   UKATEGORIE         UART  \
# count  2310.000000  2310.000000  2310.000000  2310.000000  2310.000000
# mean      6.791775    13.219913     4.040693     2.912987     3.555844
# ...

# %%
dfall=dfland2016
dfall.describe()
# Out:
#                 FID      OBJECTID   ULAND      UREGBEZ       UKREIS  \
# count   2206.000000   2206.000000  2206.0  2206.000000  2206.000000
# mean   87810.066183  87811.066183     2.0     3.322756     6.644152
# std    26929.384655  26929.384655     0.0     1.700500     4.684982
# min     6188.000000   6189.000000     2.0     1.000000     1.000000
# 25%    95210.500000  95211.500000     2.0     2.000000     3.000000
# 50%    96654.000000  96655.000000     2.0     3.000000     5.000000
# 75%    98069.750000  98070.750000     2.0     5.000000     9.000000
# max    99950.000000  99951.000000     2.0     7.000000    20.000000
#
#          UGEMEINDE   UJAHR       UMONAT      USTUNDE   UWOCHENTAG  ...  \
# count  2206.000000  2206.0  2206.000000  2206.000000  2206.000000  ...
# mean    347.585222  2016.0     6.908432    13.311423     4.125567  ...
# std     168.803837     0.0     2.853132     4.583766     1.705030  ...
# ...

# %%
dfall=pd.concat([dfland2019,dfland2018,dfland2016,dfland2017], ignore_index=True)
dfall.describe()
# Out:
#             OBJECTID   ULAND      UREGBEZ       UKREIS    UGEMEINDE  \
# count    6696.000000  9019.0  9019.000000  9019.000000  9019.000000
# mean   114818.037784     2.0     3.336179     6.573013   348.808848
# std     44467.517482     0.0     1.702043     4.626534   168.811413
# min      6155.000000     2.0     1.000000     1.000000   101.000000
# 25%     96888.250000     2.0     2.000000     3.000000   212.000000
# 50%    123189.500000     2.0     3.000000     5.000000   320.000000
# 75%    158889.750000     2.0     5.000000     9.000000   508.000000
# max    163331.000000     2.0     7.000000    20.000000   718.000000
#
#              UJAHR       UMONAT      USTUNDE   UWOCHENTAG   UKATEGORIE  ...  \
# count  9019.000000  9019.000000  9019.000000  9019.000000  9019.000000  ...
# mean   2017.525225     6.855305    13.233285     4.062535     2.905200  ...
# std       1.118456     2.949343     4.578789     1.696236     0.297089  ...
# ...

# %%
sns.countplot(data=dfall, x="UMONAT")
#label der Daten setzen
# Out:
# <AxesSubplot:xlabel='UMONAT', ylabel='count'>

# %%
sns.countplot(data=dfall, x="LICHT")
# Out:
# <AxesSubplot:xlabel='LICHT', ylabel='count'>

# %%
sns.countplot(data=dfall, x="ULICHTVERH")
# Out:
# <AxesSubplot:xlabel='ULICHTVERH', ylabel='count'>

# %%
dfall.head()
# Out:
#    OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  USTUNDE  \
# 0    6155.0      2        3       7        319   2019       1       17
# 1    6187.0      2        2      12        225   2019       4       14
# 2    6223.0      2        3       8        320   2019       1        8
# 3    6274.0      2        2       5        215   2019       3        8
# 4    6279.0      2        2      14        227   2019       2       13
#
#    UWOCHENTAG  UKATEGORIE  ...                  LINREFY          XGCSWGS84  \
# 0           2           3  ...  5942453,488371437400000  9,909801000000073
# 1           5           3  ...  5936709,515000000600000  9,823166851000053
# 2           6           3  ...  5941388,377077335500000  9,907525838000026
# 3           4           3  ...  5935355,815000003200000  9,931504854000025
# 4           2           3  ...  5937130,482922792400000  9,777262785000062
#
#             YGCSWGS84  STRZUSTAND  OBJECTID_1  IstSonstig  FID  IstStrasse  \
# ...

# %%
dfall.loc[dfall['ULAND']==2, "ULAND"] = "Hamburg"

# %%
dfall.describe()
# Out:
#             OBJECTID      UREGBEZ       UKREIS    UGEMEINDE        UJAHR  \
# count    6696.000000  9019.000000  9019.000000  9019.000000  9019.000000
# mean   114818.037784     3.336179     6.573013   348.808848  2017.525225
# std     44467.517482     1.702043     4.626534   168.811413     1.118456
# min      6155.000000     1.000000     1.000000   101.000000  2016.000000
# 25%     96888.250000     2.000000     3.000000   212.000000  2017.000000
# 50%    123189.500000     3.000000     5.000000   320.000000  2018.000000
# 75%    158889.750000     5.000000     9.000000   508.000000  2019.000000
# max    163331.000000     7.000000    20.000000   718.000000  2019.000000
#
#             UMONAT      USTUNDE   UWOCHENTAG   UKATEGORIE         UART  ...  \
# count  9019.000000  9019.000000  9019.000000  9019.000000  9019.000000  ...
# mean      6.855305    13.233285     4.062535     2.905200     3.628784  ...
# std       2.949343     4.578789     1.696236     0.297089     1.948812  ...
# ...

# %%
dfall.loc[dfall['UWOCHENTAG']==1, "UWOCHENTAG"] = "Sonntag"
dfall.loc[dfall['UWOCHENTAG']==2, "UWOCHENTAG"] = "Montag"
dfall.loc[dfall['UWOCHENTAG']==3, "UWOCHENTAG"] = "Dienstag"
dfall.loc[dfall['UWOCHENTAG']==4, "UWOCHENTAG"] = "Mittwoch"
dfall.loc[dfall['UWOCHENTAG']==5, "UWOCHENTAG"] = "Donnerstag"
dfall.loc[dfall['UWOCHENTAG']==6, "UWOCHENTAG"] = "Freitag"
dfall.loc[dfall['UWOCHENTAG']==7, "UWOCHENTAG"] = "Samstag"

# %%
sns.countplot(data=dfall, x="UWOCHENTAG")
#todo Reihenfolge
# Out:
# <AxesSubplot:xlabel='UWOCHENTAG', ylabel='count'>

# %%
sns.countplot(data=dfall, y="UKREIS")
# Out:
# <AxesSubplot:xlabel='count', ylabel='UKREIS'>

# %%
dfall.value_counts()
# Out:
# Series([], dtype: int64)

# %%
dfall.count()
# Out:
# OBJECTID       6696
# ULAND          9019
# UREGBEZ        9019
# UKREIS         9019
# UGEMEINDE      9019
# UJAHR          9019
# UMONAT         9019
# USTUNDE        9019
# UWOCHENTAG     9019
# UKATEGORIE     9019
# UART           9019
# UTYP1          9019
# ULICHTVERH     6839
# IstRad         9019
# IstPKW         9019
# IstFuss        9019
# IstKrad        9019
# IstGkfz        6839
# IstSonstige    2310
# LINREFX        9019
# LINREFY        9019
# XGCSWGS84      9019
# YGCSWGS84      9019
# STRZUSTAND     6813
# OBJECTID_1     2323
# IstSonstig     6709
# FID            2206
# IstStrasse     2206
# UIDENTSTLA     2180
# LICHT          2180
# dtype: int64

# %%
dfall.groupby(["USTUNDE","UWOCHENTAG"]).count()
# Out:
#                     OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  \
# USTUNDE UWOCHENTAG
# 0       Dienstag           1      2        2       2          2      2
#         Donnerstag         6      8        8       8          8      8
#         Freitag            9     12       12      12         12     12
#         Mittwoch           5      7        7       7          7      7
#         Montag             1      1        1       1          1      1
# ...                      ...    ...      ...     ...        ...    ...
# 23      Freitag           13     17       17      17         17     17
#         Mittwoch          10     15       15      15         15     15
#         Montag             4      5        5       5          5      5
#         Samstag           11     13       13      13         13     13
#         Sonntag            6      8        8       8          8      8
#
#                     UMONAT  UKATEGORIE  UART  UTYP1  ...  LINREFY  XGCSWGS84  \
# ...

# %%
dfall["USTUNDE"].value_counts()
# Out:
# 16    815
# 17    764
# 7     743
# 8     737
# 15    710
# 18    666
# 14    661
# 13    616
# 9     535
# 12    478
# 19    442
# 11    438
# 10    396
# 20    244
# 6     178
# 21    158
# 22    132
# 23     79
# 5      77
# 0      49
# 1      38
# 2      22
# 4      22
# 3      19
# Name: USTUNDE, dtype: int64

# %%
dfall["UMONAT"].value_counts()
# Out:
# 6     1208
# 9     1022
# 8      956
# 7      946
# 5      942
# 4      772
# 10     746
# 11     673
# 12     489
# 3      458
# 1      405
# 2      402
# Name: UMONAT, dtype: int64

# %%
sns.countplot(data=dfall, x="UREGBEZ")
# Out:
# <AxesSubplot:xlabel='UREGBEZ', ylabel='count'>

# %%
dfall.loc[dfall["UREGBEZ"]==1, "UREGBEZ"] = "HH-Mitte"
dfall.loc[dfall["UREGBEZ"]==2, "UREGBEZ"] = "Altona"
dfall.loc[dfall['UREGBEZ']==3, "UREGBEZ"] = "Eimsbüttel"
dfall.loc[dfall['UREGBEZ']==4, "UREGBEZ"] = "HH-Nord"
dfall.loc[dfall['UREGBEZ']==5, "UREGBEZ"] = "Wandsbek"
dfall.loc[dfall['UREGBEZ']==6, "UREGBEZ"] = "Bergdorf"
dfall.loc[dfall['UREGBEZ']==7, "UREGBEZ"] = "Harburg"

# %%
sns.countplot(data=dfall, x="UREGBEZ")
# Out:
# <AxesSubplot:xlabel='UREGBEZ', ylabel='count'>

# %%
dfall["UREGBEZ"].value_counts()
# Out:
# HH-Nord       1759
# HH-Mitte      1708
# Wandsbek      1623
# Eimsbüttel    1569
# Altona        1514
# Bergdorf       427
# Harburg        419
# Name: UREGBEZ, dtype: int64

# %%
sns.countplot(x="UMONAT", hue="UJAHR", data=dfall)
# Out:
# <AxesSubplot:xlabel='UMONAT', ylabel='count'>

# %%
sns.catplot(x="UJAHR",  col="UKREIS", col_wrap=5,
                data=dfall, kind="count",
                height=2.5, aspect=.8);
