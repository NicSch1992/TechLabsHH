# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "2016/Unfallorte_2016_LinRef.txt"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-d7c74b3a0fad> in <module>
# ----> 1 import geopandas as gpd
#       2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
# !pip install pandas

# %%
# !pip uninstall wheel
# !pip uninstall pipwin

# !pipwin uninstall numpy
# !pipwin uninstall pandas
# !pipwin uninstall shapely
# !pipwin uninstall gdal
# !pipwin uninstall fiona
# !pipwin uninstall pyproj
# !pipwin uninstall six
# !pipwin uninstall rtree
# !pipwin uninstall geopandas

# %%
pip install seaborn

# %%
# !pip install seaborn

# %%
df = pd.read_csv(file_path, sep=";")

# %%
df.head()
# Out:
#    FID  OBJECTID  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  USTUNDE  \
# 0    0         1      1        0      53        120   2016       1        9
# 1    1         2      1        0      57         10   2016       1       17
# 2    2         3      1        0      62          8   2016       1        0
# 3    3         4      1        0       3          0   2016       1       15
# 4    4         5      1        0      55         28   2016       1       14
#
#    UWOCHENTAG  ...  IstRad  IstPKW  IstFuss  IstKrad  IstGkfz  IstSonstig  \
# 0           5  ...       0       1        0        0        0           0
# 1           3  ...       0       1        0        0        0           0
# 2           5  ...       0       1        0        0        0           0
# 3           5  ...       1       0        0        0        0           1
# 4           1  ...       0       1        0        0        0           0
#
# ...

# %%
df.describe()
# Out:
#                  FID       OBJECTID          ULAND        UREGBEZ  \
# count  151673.000000  151673.000000  151673.000000  151673.000000
# mean    75836.000000   75837.000000       7.588325       3.058428
# std     43784.368027   43784.368027       3.100031       2.136635
# min         0.000000       1.000000       1.000000       0.000000
# 25%     37918.000000   37919.000000       6.000000       1.000000
# 50%     75836.000000   75837.000000       8.000000       3.000000
# 75%    113754.000000  113755.000000       9.000000       5.000000
# max    151672.000000  151673.000000      14.000000       7.000000
#
#               UKREIS      UGEMEINDE     UJAHR         UMONAT        USTUNDE  \
# count  151673.000000  151673.000000  151673.0  151673.000000  151673.000000
# mean       40.645560      79.723425    2016.0       6.754353      13.296908
# std        25.549715     111.305504       0.0       3.220686       4.857073
# ...

# %%
sns.countplot(data=df, x="USTUNDE")
# Out:
# <AxesSubplot:xlabel='USTUNDE', ylabel='count'>
